# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Михаил, привет!</b> Мы рады тебя видеть на территории код-ревьюеров 😎. Ты проделал большую работу над проектом, но давай познакомимся и сделаем его еще лучше! У нас тут своя атмосфера и несколько правил:
#
#
# 1. Меня зовут Александр Матвеевский. Я работаю код-ревьюером, моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать дата-специалистом.
# 2. Общаемся на ты.
# 3. Если хочешь написать, спросить - не нужно стесняться. Только выбери свой цвет для комментария.
# 4. Это учебный проект, тут можно не бояться сделать ошибку.
# 5. У нас с тобой 6 попыток для сдачи проекта.
# 6. Let's Go!
#
# ---
#
# Я буду красить комментарии цветом, пожалуйста, не удаляй их:
#
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий  говорит о том, что было сделано что-то качественное и правильное =)
# </div>
#
# ---
#
# Предлагаю работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарии студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее. Если будут какие-нибудь вопросы по моим комментариям, пиши, будем разбираться вместе :)
#
# ---

# %% [markdown]
# **Цель исследования:**

# %% [markdown]
# - изучить и обработать датасеты
# - исследовать данные
# - объединить данные для анализа
# - создать датафрейм с агрегированными данными
# - проверить гипотезы

# %% [markdown]
# **Ход исследования**

# %% [markdown]
# - обработать данные из датасетов о пользователях, их поездках и подписках
# - оценить кол-во поездок в зависимости от города, времени, возраста пользователей, наличии или отсутсвии подписки и расстояния
# - создать агрегированный датафрейм для проверки гипотез
# - проверить гипотезы: "Кто в среднем больше времени использует электросамокаты - пользователи с подпиской или без неё?", "Сильно ли изнашивают самокаты пользователи с подпиской?", "Кто больше приносит помесячной выручки - пользователей с подпиской и без неё?"

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Супер, старайся, пожалуйста, придерживаться этой стратегии в дальнейших проектах =)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
#
#
# __Комментарий от ревьюера №1__
#
#
# Отличная практика - расписывать цель и основные этапы своими словами (этот навык очень поможет на фильнальном проекте). Хорошо было бы добавить ход и цель исследования. Вот мой личный пример из 3 проекта:
#
# ![image.png](attachment:image.png)
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats as st

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Хорошо, модули загружены
# </div>

# %% [markdown]
# #### Шаг 1. Загрузка данных

# %%
try:
    df1 = pd.read_csv('/datasets/users_go.csv', sep = ',')
except:
    df1 = pd.read_csv('https://code.s3.yandex.net/datasets/users_go.csv', sep = ',')
    
try:
    df2 = pd.read_csv('/datasets/rides_go.csv', sep = ',')
except:
    df2 = pd.read_csv('https://code.s3.yandex.net/datasets/rides_go.csv', sep = ',')
    
try:
    df3 = pd.read_csv('/datasets/subscriptions_go.csv', sep = ',')
except:
    df3 = pd.read_csv('https://code.s3.yandex.net/datasets/subscriptions_go.csv', sep = ',')

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Для подгрузки данных можно использовать конструкцию `try-except`, она поможет избежать потенциальных ошибок при загрузке данных, связанных, например, с некорректным указанием путей.
#
# Подробнее о конструкции по ссылке:
#
# https://pythonworld.ru/tipy-dannyx-v-python/isklyucheniya-v-python-konstrukciya-try-except-dlya-obrabotki-isklyuchenij.html
#
# Либо же можно использовать стандартную библиотеку os:
#
# https://pythonworld.ru/moduli/modul-os.html
#
#
# Несколько интересных статей кейсы использования конструкции:
#
# https://www.programiz.com/python-programming/exception-handling
#
# https://towardsdatascience.com/do-not-abuse-try-except-in-python-d9b8ee59e23b
#
# https://www.techbeamers.com/use-try-except-python/
#
# Как вариант в try можно указать корректные пути (в нашем случае глобальные) в except - некорректные (локальные). Можно также специфицровать тип ошибки, FileNotFoundError или задать кастомный тип ошибки (FilePathError, например)
#
# Она полезна, если ты работаешь локально, а потом подгружаешь проект на платформу. Конструкция позволит не падать коду и локально, и на сервере ЯП, так как если не сработает один блок с путями, сработает другой.
#
# Ну и вообще, в целом полезно про эту констуркцию знать, она универсальна и может быть использована в разных задачах.
# </div>

# %%
df1.info()
df1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1565 entries, 0 to 1564
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            1565 non-null   int64
#  1   name               1565 non-null   object
#  2   age                1565 non-null   int64
#  3   city               1565 non-null   object
#  4   subscription_type  1565 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 61.3+ KB
#    user_id        name  age            city subscription_type
# 0        1        Кира   22          Тюмень             ultra
# 1        2   Станислав   31            Омск             ultra
# 2        3     Алексей   20          Москва             ultra
# 3        4  Константин   26  Ростов-на-Дону             ultra
# 4        5       Адель   28            Омск             ultra

# %%
df2.info()
df2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18068 entries, 0 to 18067
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   18068 non-null  int64
#  1   distance  18068 non-null  float64
#  2   duration  18068 non-null  float64
#  3   date      18068 non-null  object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 564.8+ KB
#    user_id     distance   duration        date
# 0        1  4409.919140  25.599769  2021-01-01
# 1        1  2617.592153  15.816871  2021-01-18
# 2        1   754.159807   6.232113  2021-04-20
# 3        1  2694.783254  18.511000  2021-08-11
# 4        1  4028.687306  26.265803  2021-08-28

# %%
df3.info()
df3.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   subscription_type  2 non-null      object
#  1   minute_price       2 non-null      int64
#  2   start_ride_price   2 non-null      int64
#  3   subscription_fee   2 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 192.0+ bytes
#   subscription_type  minute_price  start_ride_price  subscription_fee
# 0              free             8                50                 0
# 1             ultra             6                 0               199

# %% [markdown]
# Самый большой датафрейм - второй (18068 строк), самый маленикий - третий (всего 2 строки). Время во втором датафрейме имеет неправильный формат.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
#
# Отлично! Первый взгляд на данные есть

# %% [markdown]
# #### Шаг 2. Предобработка данных

# %% [markdown]
# Приведём столбец 'date' к типу datetime:

# %%
df2['date'] = pd.to_datetime(
    df2['date'], format='%Y-%m-%d'
)
df2.dtypes
# Out:
# user_id              int64
# distance           float64
# duration           float64
# date        datetime64[ns]
# dtype: object

# %% [markdown]
# Создадим столбец с номером месяца:

# %%
df2['month'] = pd.DatetimeIndex(df2['date']).month
df2.head()
# Out:
#    user_id     distance   duration       date  month
# 0        1  4409.919140  25.599769 2021-01-01      1
# 1        1  2617.592153  15.816871 2021-01-18      1
# 2        1   754.159807   6.232113 2021-04-20      4
# 3        1  2694.783254  18.511000 2021-08-11      8
# 4        1  4028.687306  26.265803 2021-08-28      8

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Хорошо бы проверить за какой период у нас данные. Проверить столбец длительности на предмет наличия аномалий. Например, если у нас разные года то январь 2021 и январь 2022 будут под одной цифрой (1).
# </div>

# %% [markdown]
# Проверим пропуски в датафреймах:

# %%
df1.isna().sum()
# Out:
# user_id              0
# name                 0
# age                  0
# city                 0
# subscription_type    0
# dtype: int64

# %%
df2.isna().sum()
# Out:
# user_id     0
# distance    0
# duration    0
# date        0
# month       0
# dtype: int64

# %%
df3.isna().sum()
# Out:
# subscription_type    0
# minute_price         0
# start_ride_price     0
# subscription_fee     0
# dtype: int64

# %% [markdown]
# Пропусков нет, проверим датафреймы на дубликаты:

# %%
df1.duplicated().sum()
# Out:
# 31

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df3.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дубликаты есть в первом датафрейме, удалим их из датафрейма:

# %%
df1 = df1.drop_duplicates().reset_index(drop=True)
df1.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Проверка на дубликаты - основа предобработки данных

# %% [markdown]
# #### Шаг 3. Исследовательский анализ данных

# %% [markdown]
# **3.1 Частота встречаемости городов**

# %% [markdown]
# Информация о городах у нас в первом датафрейме, посчитаем количество городов и выведем столбчатую диаграмму:

# %%
df1['city'].value_counts().plot.bar(figsize=(12,5), grid = True)
plt.title('Частота встречаемости городов', fontsize=16, pad=20)
plt.xlabel('Города', labelpad=10, fontsize=14)
plt.ylabel('Частота', labelpad=20, fontsize=14)
plt.rc('font', size=12)

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# График по данным построен корректно, но не оформлен до конца. Суть в том, что график должен быть наглядным без контекста (т.к. в реальной практике ты будешь показывать презентации или отчет сторонним людям).
#
# Тебе необходимо проследить чтобы всегда был заголовок и подписаны оси. Доработай этот момент пожалуйста.
#
# Данное замечания относится ко всему проекту и перепроверь его самостоятельно. Далее не буду акцентировать на этом внимание

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
#  Да, так лучше)

# %% [markdown]
# Меньше всего пользователей в Москве, больше всего - в Пятигорске.

# %% [markdown]
# **3.2 Соотношение пользователей с подпиской и без неё**

# %%
a = len(df1.query('subscription_type == "ultra"')) / len(df1.query('subscription_type == "free"')) * 100
print('Соотношение пользователей с подпиской и без неё:', '{0:.2f}'.format(a), '%')
# Out:
# Соотношение пользователей с подпиской и без неё: 83.71 %

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Отсутствует визуализация

# %% [markdown]
# <div class="alert alert-info"> <b>Миша:</b> Не совсем понятно зачем нужна визуализация если речь идёт про одно соотношение, вот plot.bar(), но непонятно зачем он тут нужен:</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Указание в ТЗ
#
# ![image.png](attachment:image.png)

# %%
df1['subscription_type'].value_counts().plot.bar()
plt.title('Пользователи с подпиской и без', pad =10)
# Out:
# Text(0.5, 1.0, 'Пользователи с подпиской и без')

# %% [markdown]
# **3.3 Возраст пользователей**

# %%
df1['age'].hist(bins=50)
plt.xlabel('Возраст пользователей, лет', labelpad=10, fontsize=14)
plt.ylabel('Частота', labelpad=20, fontsize=14)
plt.rc('font', size=12)

# %%
df1[['age']].boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Больше всего пользователей с возрастом 25 лет, в основном возраст пользователей распределён между 20 и 30 годами. Также по боксплоту можно увидеть 4 выброса: 1 внизу и 3 вверху.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Основная часть пользователей возрастом от 22 до 28 лет. Медиана: 25 лет. Все что меньше 15 лет и больше 40 можно считать редкими значениями.

# %% [markdown]
# **3.4 Расстояние, которое пользователь преодолел за одну поездку**

# %%
(df2['distance']/1000).hist()
plt.title('Расстояние, которое пользователь преодолел за одну поездку', fontsize=16, pad=20)
plt.xlabel('Расстояние, км', labelpad=10, fontsize=14)
plt.ylabel('Частота', labelpad=20, fontsize=14)
plt.rc('font', size=12)

# %%
(df2['distance']/1000).describe()
# Out:
# count    18068.000000
# mean         3.070660
# std          1.116831
# min          0.000856
# 25%          2.543226
# 50%          3.133610
# 75%          3.776223
# max          7.211008
# Name: distance, dtype: float64

# %%
df2[['distance']].boxplot()
plt.title('Расстояние, которое пользователь преодолел за одну поездку', fontsize=16, pad=20)
plt.ylabel('Расстояние, м', labelpad=20, fontsize=14)
# Out:
# Text(0, 0.5, 'Расстояние, м')

# %% [markdown]
# Больше всего пользователей преодолевают расстояние в районе 3.5 км. Среднее - 3.07 км. Сильно отличающиеся значения - те которые больше 7 км.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Основная часть поездок занимает от 2500 до 3800 метров. Медиана 3133 метра. Поездки на расстояние более 5 км редки. Однако на гистограмме видно, что некоторая часть пользователей использует самокаты для коротких поездок - до 1500 м.

# %% [markdown]
# **3.5 Продолжительность поездок**

# %%
df2['duration'].hist()
plt.title('Продолжительность поездок', fontsize=16, pad=20)
plt.xlabel('Время, мин', labelpad=10, fontsize=14)
plt.ylabel('Частота', labelpad=20, fontsize=14)
plt.rc('font', size=12)

# %%
df2['duration'].describe()
# Out:
# count    18068.000000
# mean        17.805011
# std          6.091051
# min          0.500000
# 25%         13.597563
# 50%         17.678395
# 75%         21.724800
# max         40.823963
# Name: duration, dtype: float64

# %%
df2[['duration']].boxplot()
plt.title('Продолжительность поездок', fontsize=16, pad=20)
plt.ylabel('Время, мин', labelpad=20, fontsize=14)
plt.rc('font', size=12)

# %% [markdown]
# Самое распространённое время поездки - 20 минут. Среднее - 17.8 минут. Аномальные значения - выше 40 и в районе 1 минуты.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Хорошо бы графики подкрепить боксплотом

# %% [markdown]
# #### Шаг 4. Объединение данных

# %% [markdown]
# **4.1 Объединяем данные о пользователях, поездках и подписках в один датафрейм**

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#  Отсутствует проверка размерности:
#
# * размеры датасетов до объединения
# * размер результирующего датафрейма (с учетом типа объединения)

# %% [markdown]
# Для начала проверим размеры датасетов:

# %%
len(df1)
# Out:
# 1534

# %%
len(df2)
# Out:
# 18068

# %% [markdown]
# Из этого следует, что если мы объединяем два датасета по 'user_id', то у нас должно получиться 18068 строк:

# %%
df = df1.merge(df2, how='inner', on='user_id')
df.head()
# Out:
#    user_id  name  age    city subscription_type     distance   duration  \
# 0        1  Кира   22  Тюмень             ultra  4409.919140  25.599769
# 1        1  Кира   22  Тюмень             ultra  2617.592153  15.816871
# 2        1  Кира   22  Тюмень             ultra   754.159807   6.232113
# 3        1  Кира   22  Тюмень             ultra  2694.783254  18.511000
# 4        1  Кира   22  Тюмень             ultra  4028.687306  26.265803
#
#         date  month
# 0 2021-01-01      1
# 1 2021-01-18      1
# 2 2021-04-20      4
# 3 2021-08-11      8
# 4 2021-08-28      8

# %%
len(df)
# Out:
# 18068

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Отлично. Проверка размерности датасетов проведена

# %% [markdown]
# **4.2 Создадим ещё два датафрейма для пользователей с и без подписки**

# %%
df_with_sub = df.query('subscription_type == "ultra"')
df_with_sub['subscription_type'].unique()
# Out:
# array(['ultra'], dtype=object)

# %%
df_without_sub = df.query('subscription_type != "ultra"')
df_without_sub['subscription_type'].unique()
# Out:
# array(['free'], dtype=object)

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Отлично. Датасеты выведены корректно

# %% [markdown]
# **4.3 Визуализируем информацию о расстоянии и времени поездок для пользователей обеих категорий**

# %% [markdown]
# Сначала для расстояния:

# %%
plt.hist([df_with_sub['distance']/1000, df_without_sub['distance']/1000], bins=30, label=['с подпиской', 'без подписки'])
plt.legend(loc='upper left')
plt.grid(True)
plt.title('Расстояние за одну поездку', fontsize=16, pad=20)
plt.xlabel('Расстояние, км', labelpad=10, fontsize=14)
plt.ylabel('Частота', labelpad=20, fontsize=14)
plt.rc('font', size=12)
plt.show()

# %% [markdown]
# Для пользователей с подпиской самая распространённая дистанция - 3 км. Для пользователей без неё - примерно 2.6 км. Так как пользователей с подпиской меньше (83.71 % от пользователей без подписки), то длина каждого столбца в гистограмме при одинаковом распределении будет на 0.8371 меньше, но даже при этом количество поездок на 3 км больше. Из этого можно сделать вывод, что распределение у пользователей без подписки более равномерно.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# У пользователей без подписки значительно больше коротких поездок - до 1 км и в целом максимальная дальность поездки выше, чем у платных пользователей.

# %% [markdown]
# Теперь визуализируем информацию для времени поездок:

# %%
plt.hist([df_with_sub['duration'], df_without_sub['duration']], bins=30, label=['с подпиской', 'без подписки'])
plt.legend(loc='upper left')
plt.grid(True)
plt.title('Время за одну поездку', fontsize=16, pad=20)
plt.xlabel('Время, мин', labelpad=10, fontsize=14)
plt.ylabel('Частота', labelpad=20, fontsize=14)
plt.rc('font', size=12)
plt.show()

# %% [markdown]
# Для пользователей с подпиской самое распространённое время - примерно 18 минут. Для пользователей без неё - примерно 17 минут.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# В целом картина такая же - распределение внутри категорий имеют одинаковый профиль (и одинаковый с профилем распределения до разбивки на категории - строили на ранних этапах), но в каждом из диапазонов бесплатных пользователей чуть больше, но их, как мы помним, и в целом больше.
#
# Краевые значения (минимум и максимум) у бесплатных пользователей смещены влево относительно платных подписчиков - стоимость минуты все-таки больше, значит часть пользователей торопится завершить поездки за меньший срок. Но при этом визуально среднее значение не сильно смещено

# %% [markdown]
# #### Шаг 5. Подсчёт выручки

# %% [markdown]
# **5.1 Создадим датафрейм с агрегированными данными о поездках на основе датафрейма с объединёнными данными из шага 4**

# %% [markdown]
# Создадим сводную таблицу с суммарным расстоянием, временем, количеством поездок для каждого пользователя в определённый месяц:

# %%
new_df = df.groupby(['user_id', 'subscription_type', 'month']).agg({'distance': ['sum'], 'duration': ['sum', 'count']}).reset_index(['subscription_type'])
new_df.columns = ['subscription_type', 'distance', 'duration', 'count']
new_df.head(10)
# Out:
#               subscription_type      distance   duration  count
# user_id month
# 1       1                 ultra   7027.511294  41.416640      2
#         4                 ultra    754.159807   6.232113      1
#         8                 ultra   6723.470560  44.776802      2
#         10                ultra   5809.911100  31.578017      2
#         11                ultra   7003.499363  53.397424      3
#         12                ultra   6751.629942  27.203912      2
# 2       3                 ultra  10187.723006  60.959959      3
#         4                 ultra   6164.381824  39.048633      2
#         6                 ultra   3255.338202  13.851127      1
#         7                 ultra   6780.722964  46.170157      2

# %% [markdown]
# **5.2 Добавим в этот датафрейм столбец с помесячной выручкой для каждого пользователя**

# %% [markdown]
# Округлим значения времени:

# %%
new_df['duration'] = np.ceil(new_df['duration'])
new_df['duration'] = new_df['duration'].astype(int)
new_df.head()
# Out:
#               subscription_type     distance  duration  count
# user_id month
# 1       1                 ultra  7027.511294        42      2
#         4                 ultra   754.159807         7      1
#         8                 ultra  6723.470560        45      2
#         10                ultra  5809.911100        32      2
#         11                ultra  7003.499363        54      3

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Отлично, что используешь именно np.ceil(). Грамотный шаг

# %% [markdown]
# Теперь применим функцию для расчёта помесячной выручки для пользователей с подпиской и без:

# %%
def month_earn(row):
    sub = row['subscription_type']
    count = row['count']
    duration = row['duration']
    if sub == 'ultra':
        return (199 + duration * 6)
    else:
        return (50 * count + 8 * duration)
    

new_df['month_earnings'] = new_df.apply(month_earn, axis=1)
new_df.head()
# Out:
#               subscription_type     distance  duration  count  month_earnings
# user_id month
# 1       1                 ultra  7027.511294        42      2             451
#         4                 ultra   754.159807         7      1             241
#         8                 ultra  6723.470560        45      2             469
#         10                ultra  5809.911100        32      2             391
#         11                ultra  7003.499363        54      3             523

# %% [markdown]
# Полученные результаты тоже предлагаю округлить:

# %%
new_df['month_earnings'] = np.ceil(new_df['month_earnings'])
new_df['month_earnings'] = new_df['month_earnings'].astype(int)
new_df.head(10)
# Out:
#               subscription_type      distance  duration  count  month_earnings
# user_id month
# 1       1                 ultra   7027.511294        42      2             451
#         4                 ultra    754.159807         7      1             241
#         8                 ultra   6723.470560        45      2             469
#         10                ultra   5809.911100        32      2             391
#         11                ultra   7003.499363        54      3             523
#         12                ultra   6751.629942        28      2             367
# 2       3                 ultra  10187.723006        61      3             565
#         4                 ultra   6164.381824        40      2             439
#         6                 ultra   3255.338202        14      1             283
#         7                 ultra   6780.722964        47      2             481

# %%
new_df
# Out:
#               subscription_type      distance  duration  count  month_earnings
# user_id month
# 1       1                 ultra   7027.511294        42      2             451
#         4                 ultra    754.159807         7      1             241
#         8                 ultra   6723.470560        45      2             469
#         10                ultra   5809.911100        32      2             391
#         11                ultra   7003.499363        54      3             523
# ...                         ...           ...       ...    ...             ...
# 1534    6                  free   3409.468534        25      2             300
#         8                  free   7622.453034        48      2             484
#         9                  free   4928.173852        23      1             234
#         11                 free  13350.015305        77      4             816
#         12                 free   2371.711192        16      1             178
#
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Некорреткный расчёт. Нам нужно рассчитать именно месячную выручку от пользователя

# %% [markdown]
# <div class="alert alert-info"> <b>Миша:</b> А как её корректно рассчитать? Я взял общее время, которое до этого округлил, в случае наличии подписки умножил общее количество минут на цену одной минуты и разделил на 12 (количество месяцев) и добавил помесячную оплату, т. е. формула - 199 + (кол-во минут * 6) / 12. Соответсвенно, в случае без неё формула следующая - (50 * кол-во стартов(т. е. count) + 8 * кол-во минут)/12. Т.е. в данном случае я беру среднюю месячную выручку от каждого клиента. Если высчитать для каждого пользователя доход за каждый месяц, то тогда совершенно непонятно какой конкретно месяц брать в пункте 6.3, или нам это неважно?</div>

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №2__
#
#
# Для расчета ежемесячной выручки понадобится агрегированная таблица по каждому пользователю с информацией о суммарной дистанции, длительности и количестве поездок за каждый месяц. В сводной таблице присоединnm информаци. о подписке и стоимостях поездок
#
# ---
#
# Т.е. для каждого пользователя дожнен быть так:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от тимлида №3__
#
# Да, теперь коррекный расчёт и размерность

# %% [markdown]
# #### Шаг 6. Проверка гипотез

# %% [markdown]
# **6.1 Сравним кто в среднем больше времени использует электросамокаты - пользователи с подпиской или без неё**

# %% [markdown]
# Сформулируем нулевую и альтернативную гипотезу:
# - Нулевая гипотеза (H0): Среднее время поездки у пользователей с подпиской и без подписки одинаковое m1 = m2
# - Альтернативная гипотеза (H1): Среднее время поездки у пользователей с подпиской больше чем у пользователей без подписки m1 > m2
#
# Проверим гипотезу, уровень статистической значимости по умолчанию равен 0.05:

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Отсутствует формулировка гипотез в проекте (Но/Н1). Добавь, пожалуйста, по проекту

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №2__
#
# Не совсем. Смотри, как грамотнее на примере этой гипотезы (поправить в остальных, пожалуйста. По аналогии) ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №3__
#
# Верная интерпретация нулевой и альтернативной гипотез
# </div>

# %%
sub = df.query('subscription_type == "ultra"')['duration']
without_sub = df.query('subscription_type != "ultra"')['duration']

alpha = 0.05 

results = st.ttest_ind(sub, without_sub, equal_var = False, alternative = 'greater')

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 5.6757813771289775e-37
# Отвергаем нулевую гипотезу

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Немного не те данные взяты в гипотезе. Например в переменной `df_with_sub` 6500 данных. А в `sub` всего 698 строк. Нам нужны все данные

# %% [markdown]
# <div class="alert alert-info"> <b>Миша:</b> Я брал датасет df2_with_sub, а не df_with_sub, получается df2_with_sub  имеет 18068 строк, а sub - 6499, что как мне кажется правильно.</div>

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №2__
#
# Михаил, смотри: У нас есть готовая сводная таблица `df`. Нужно взять из данные из объединенной таблицы `df` данные по платникам и бесплатинкам

# %% [markdown]
# Из этого делаем вывод, что пользователи с подпиской в среднем используют электросамокаты более продолжительно по времени. То есть пользователи с подпиской более выгодны для компании.

# %% [markdown]
# **6.2 Проверим сильно ли изнашивают самокаты пользователи с подпиской**

# %% [markdown]
# Расстояние одной поездки в 3130 метров — оптимальное с точки зрения износа самоката. Проверим насколько пользователи с подпиской их изнашивают с помощью гипотезы:
# - Нулевая гипотеза (H0): Средняя дистанция поездки у пользователей с подпиской равна 3130 метрам m = 3150
# - Альтернативная гипотеза (H1): Средняя дистанция поездки у пользователей с подпиской рбольше 3130 метров m > 3150

# %%
sub = df.query('subscription_type == "ultra"')['distance']

optimal_distance = 3130

alpha = 0.05 # уровень статистической значимости

results = st.ttest_1samp(sub, optimal_distance, alternative='greater')

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не отвергаем нулевую гипотезу')
# Out:
# p-значение: 0.9195368847849785
# Не отвергаем нулевую гипотезу

# %% [markdown]
# Пользователи с подпиской проезжают в среднем больше 3130 метров, соответсвтеннно, изнашивают электросамокаты.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Смотри, поскольку оптимальное расстояние по износу составляет 3130 м, значит большее расстояние приводит к повышенному износу самоката. Следовательно имеет смысл проверить одностороннюю гипотезу, что расстояние, которое проезжают пользователи с подпиской не превышает оптимального расстояния в 3130 м.
#
# То есть в статистическом тесте стоит поставить параметр alternative = 'greater'

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
# Корректно. Молодец

# %% [markdown]
# **6.3 Сравним помесячную выручку пользователей с подпиской и без неё**

# %% [markdown]
# Гипотеза такая же как в параграфе 6.1:

# %%
sub = new_df.query('subscription_type == "ultra"')['month_earnings']
without_sub = new_df.query('subscription_type != "ultra"')['month_earnings']

alpha = 0.05 # уровень статистической значимости

results = st.ttest_ind(sub, without_sub, equal_var = False, alternative = 'greater')

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 1.0718729651261336e-44
# Отвергаем нулевую гипотезу

# %% [markdown]
# Пользователи с подпиской в среднем приносят больше прибыли, чем пользователи без неё.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Тут аналогично первой гипотезе

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №2__
# Данные изменятся после корректировки расчёта выручки

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №3__
#
# Методологически проверка гипотез проведена верно и наглядный вывод результатов

# %% [markdown]
# # Вывод

# %% [markdown]
# В данной работе мы проанализировали данные сервиса аренды самокатов GoFast. Был изменён формат времени и убраны дубликаты. Была изучена следующая информация:
# - частота встречаемости городов: меньше всего пользователей в Москве, больше всего - в Пятигорске;
# - cоотношение пользователей с подпиской и без неё: 83.71 %;
# - возраст пользователей: больше всего пользователей с возрастом 25 лет, в основном возраст пользователей распределён между 20 и 30 годами;
# - расстояние, которое пользователь преодолел за одну поездку: основная часть поездок занимает от 2500 до 3800 метров, медиана 3133 метра
# - продолжительность поездок: самое распространённое время поездки - 20 минут, среднее - 17.8 минут;
# -  информация о расстоянии и времени поездок для пользователей обеих категорий: у пользователей без подписки значительно больше коротких поездок - до 1 км и в целом максимальная дальность поездки выше, чем у платных пользователей,  для пользователей с подпиской самое распространённое время - примерно 18 минут, для пользователей без неё - примерно 17 минут.

# %% [markdown]
# Проверены и сделаны выводы по следующим гипотезам:
# - "Кто в среднем больше времени использует электросамокаты - пользователи с подпиской или без неё?" - пользователи с подпиской в среднем используют электросамокаты более продолжительно по времени, т. е. пользователи с подпиской более выгодны для компании.
# - "Сильно ли изнашивают самокаты пользователи с подпиской?" - пользователи с подпиской проезжают в среднем больше 3130 метров, соответсвтеннно, изнашивают электросамокаты, так как 3130 метров - оптимальное расстояние, не заходя за которое, электросамокат меньше изнашивается.
# - "Кто больше приносит помесячной выручки - пользователей с подпиской и без неё?" - пользователи с подпиской в среднем приносят больше прибыли, чем пользователи без неё.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №2__
#
# Итоговый вывод завершает твое исследование. А его нету...
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №2__
#
# Итоговый вывод завершает твое исследование. Представлены основные результаты полученные в ходе анализа, но не увидел каких либо рекомендаций по развитию аренды самокатов в разрезе твоего исследования. Добавь, пожалуйста
#
# Не забудь подкорректировать вывод после исправлений
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
# Комментарий от ревьюера №1 </b>
#
#
#
# У тебя получилась очень сильная и хорошая работа. Здорово, что расчеты ты сопровождаешь иллюстрациями, а так же не забываешь про комментарии, твой проект интересно проверять.
#
# ---
#
# Нужно поправить:
#
# 1) Вводная часть
#
# 2) Оформление графиков
#
# 3) Проверка  датафреймов после работы с ними
#
# 4) Анализ выгодности
#
# 5) Гипотезы
#
# 6) Финальный выовд
#
# 7) Подправить выводы, после изменений
#
# ----
#
#
# Если у тебя будут какие-то вопросы по моим комментариям - обязательно пиши! Буду ждать работу на повторное ревью :)</div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
# Комментарий от ревьюера №2 </b>
#
#
#
# Отличная работа, осталось поправить пару моментов:
#
# ---
#
# Нужно поправить:
#
#
# 1) Расчёт выручки
#
# 2) Гипотезы
#
# 3) Подправить выводы, после изменений
#
# ----
#
#
# Если у тебя будут какие-то вопросы по моим комментариям - обязательно пиши! Буду ждать работу на повторное ревью :)</div>

# %% [markdown]
# <div style="border:solid blue 3px; padding: 20px">
# <div class="alert alert-block alert-success">✔️
#
#
# __Коментарий от ревьюера №3__
#
#
# В остальном всё чудно😊. Твой проект так и просится на github =)
#
# Поздравляю с успешным завершением проекта 😊👍
# И желаю успехов в новых работах 😊
#
# ---
#
# От себя хочу порекомендовать тебе отличный метариал по статистике.
#
# * Курс "Вероятность и статистика" | Глеб Михайлов (free): https://www.youtube.com/playlist?list=PLQJ7ptkRY-xbHLLI66KdscKp_FJt0FsIi
#
# * Методы обнаружения выбросов: https://youtu.be/TOK7Kq7x0yc
#
#
# </div>
