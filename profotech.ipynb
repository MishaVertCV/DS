# %% [markdown]
# <a href="https://colab.research.google.com/github/MishaVertCV/DS/blob/main/profotech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Обработка таблиц приборов#

# %% [markdown]
# Импорт библиотек:

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Добавление таблиц:

# %%
df_T = pd.read_excel('bel.xlsx', index_col=0)
df = df_T.T
df = df.reset_index()
df.columns = df.iloc[0]
df = df.iloc [1: , :]
df.drop (df.columns [[0]], axis= 1 , inplace= True)
df = df.iloc[:, 2:]
df.head(10)
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell T89 is marked as a date but the serial value 21896534 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# 0  Серийный номер ТТЭО          Метрологическое название ТТЭО  \
# 1                  NaN                                    NaN
# 2         ЭОБ-Р 033-24  ТТЭО-35-250-0.2S/5TPE12-0.2S/5TPE12-С
# 3                  NaN                                    NaN
# 4                  NaN                                    NaN
# 5                  NaN                                    NaN
# 6                  NaN                                    NaN
# 7                  NaN                                    NaN
# 8                  NaN                                    NaN
# ...

# %% [markdown]
# Выберем определённые значения из этой таблицы:

# %%
main_number = df['Серийный номер ТТЭО'][2]
main_name = df['Метрологическое название ТТЭО'][2]
main_project = df['Название проекта'][2]
sens_type = df['Тип чувствительного элемента'][2]
phase_num = df['Количество фаз в ЭОБ'][2]
sens_nums = df['ЧЭ, зав. №'][2]
sens_num_A = sens_nums[9:16]
sens_num_B = sens_nums[26:33]
sens_num_C = sens_nums[43:50]
nom_current = df['Номинальный первичный ток, А'][2]
big_nom_cur = df['Расширенный номинальный первичный ток, А'][2]
act_current = df['Действующее значение тока установившегося режима короткого замыкания, кА'][2]
max_current = df['Предельное амплитудное значение тока короткого замыкания, кА'][2]
term_current = df['Ток термической стойкости (3с), кА'][2]
din_current = df['Ток динамической стойкости, кА'][2]
nom_volt = df['Номинальное напряжение, кВ'][2]
freq = df['Промышленная частота'][2]
