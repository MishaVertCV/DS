# %% [markdown]
# <a href="https://colab.research.google.com/github/MishaVertCV/DS/blob/main/profotech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Обработка таблиц приборов#

# %% [markdown]
# Импорт библиотек:

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Добавление таблиц:

# %%
df_T = pd.read_excel('bel.xlsx', index_col=0)
df = df_T.T
df.columns = df.iloc[0]
df = df.iloc [1: , :]

df
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:223: UserWarning: Cell T89 is marked as a date but the serial value 21896534 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# Unnamed: 1   NaN    Параметр Серийный номер ТТЭО  \
# Unnamed: 2   NaN         NaN                 NaN
# Unnamed: 3   NaN    Значение        ЭОБ-Р 033-24
# Unnamed: 4   NaN         NaN                 NaN
# Unnamed: 5   NaN         NaN                 NaN
# Unnamed: 6   NaN  Примечание                 NaN
# Unnamed: 7   NaN         NaN                 NaN
# Unnamed: 8   NaN         NaN                 NaN
# Unnamed: 9   NaN         NaN                 NaN
# Unnamed: 10  NaN         NaN                 NaN
# Unnamed: 11  NaN         NaN                 NaN
# Unnamed: 12  NaN         NaN                 NaN
# Unnamed: 13  NaN         NaN                 NaN
# Unnamed: 14  NaN         NaN                 NaN
# Unnamed: 15  NaN         NaN                 NaN
# Unnamed: 16  NaN         NaN                 NaN
# Unnamed: 17  NaN         NaN                 NaN
# Unnamed: 18  NaN         NaN                 NaN
# Unnamed: 19  NaN         NaN                 NaN
#
# Unnamed: 1           Метрологическое название ТТЭО Название проекта  \
# Unnamed: 2                                     NaN              NaN
# Unnamed: 3   ТТЭО-35-250-0.2S/5TPE12-0.2S/5TPE12-С   Белоярская АЭС
# Unnamed: 4                                     NaN              NaN
# Unnamed: 5                                     NaN              NaN
# Unnamed: 6                                     NaN              NaN
# Unnamed: 7                                     NaN              NaN
# Unnamed: 8                                     NaN              NaN
# Unnamed: 9                                     NaN              NaN
# Unnamed: 10                                    NaN              NaN
# Unnamed: 11                                    NaN              NaN
# Unnamed: 12                                    NaN              NaN
# Unnamed: 13                                    NaN              NaN
# Unnamed: 14                                    NaN              NaN
# Unnamed: 15                                    NaN   без ЧЭ (ЭОБ-Р)
# Unnamed: 16                                    NaN              NaN
# Unnamed: 17                                    NaN              NaN
# Unnamed: 18                                    NaN              NaN
# Unnamed: 19                                    NaN       ЭОБ-Р ТТЭО
#
# Unnamed: 1                        Тип чувствительного элемента  \
# Unnamed: 2                                                 NaN
# Unnamed: 3                                      без ЧЭ (ЭОБ-Р)
# Unnamed: 4                                                 NaN
# Unnamed: 5                                                 NaN
# Unnamed: 6                                                 NaN
# Unnamed: 7                                                 NaN
# Unnamed: 8                                                 NaN
# Unnamed: 9                                                 NaN
# Unnamed: 10                                                NaN
# Unnamed: 11                                               0.05
# Unnamed: 12                                               0.05
# Unnamed: 13                                                NaN
# Unnamed: 14                                                NaN
# Unnamed: 15                                  шинное исполнение
# Unnamed: 16                                                NaN
# Unnamed: 17  Колонна токовая 13,8 кВ шинного исполнения ТТЭ...
# Unnamed: 18                                                NaN
# Unnamed: 19                                             ТТЭО-Ш
#
# Unnamed: 1                                Серийный номер ЭОБ-Р  \
# Unnamed: 2                                                 NaN
# Unnamed: 3                                                 NaN
# Unnamed: 4                                                 NaN
# Unnamed: 5                                                 NaN
# Unnamed: 6                                                 NaN
# Unnamed: 7                                                 NaN
# Unnamed: 8                                                 NaN
# Unnamed: 9                                                 NaN
# Unnamed: 10                                                NaN
# Unnamed: 11                                                0.1
# Unnamed: 12                                                0.1
# Unnamed: 13                                     без SFP модуля
# Unnamed: 14                              оптический 1PPS фронт
# Unnamed: 15            шинное исполнение с изоляторами 13,8 кВ
# Unnamed: 16                                                NaN
# Unnamed: 17  Колонна токовая 13,8 кВ шинного исполнения ТТЭ...
# Unnamed: 18                                               13.8
# Unnamed: 19                                             ТТЭО-Ш
#
# Unnamed: 1  Ссылка на технологический паспорт основного ЭОБ в комплекте ТТЭО  \
# Unnamed: 2                                                 NaN
# Unnamed: 3                                                 NaN
# Unnamed: 4                                                 NaN
# Unnamed: 5                                                 NaN
# Unnamed: 6                                                 NaN
# Unnamed: 7                                                 NaN
# Unnamed: 8                                                 NaN
# Unnamed: 9                                                 NaN
# Unnamed: 10                                                NaN
# Unnamed: 11                                                0.2
# Unnamed: 12                                                0.2
# Unnamed: 13                                TX 100Mbit (медный)
# Unnamed: 14                           электрический 1PPS фронт
# Unnamed: 15                   шинное исполнение без изоляторов
# Unnamed: 16                                                NaN
# Unnamed: 17  Чувствительный элемент ТТЭО шинный ТТЭО-3.10.0...
# Unnamed: 18                                                NaN
# Unnamed: 19                                             ТТЭО-Ш
#
# Unnamed: 1                                Количество фаз в ЭОБ  \
# Unnamed: 2                                                 NaN
# Unnamed: 3                                                   3
# Unnamed: 4                                                 NaN
# Unnamed: 5                                                 NaN
# Unnamed: 6                                                 NaN
# Unnamed: 7                                                 NaN
# Unnamed: 8                                                 NaN
# Unnamed: 9                                                 NaN
# Unnamed: 10                                                NaN
# Unnamed: 11                                               0.2s
# Unnamed: 12                                                0.2
# Unnamed: 13                               TX 1000Mbit (медный)
# Unnamed: 14                            электрический 1PPS спад
# Unnamed: 15  колонна токовая с жесткой шиной без опорного и...
# Unnamed: 16                                                NaN
# Unnamed: 17  Колонна токовая без изолятора ТТЭО-3.25.00.00.000
# Unnamed: 18                                                NaN
# Unnamed: 19                                             ТТЭО-Ш
#
# Unnamed: 1                                          ЧЭ, зав. №  ...  \
# Unnamed: 2                                                 NaN  ...
# Unnamed: 3   фаза А - 0071-24\nфаза В - 0072-24\nфаза С - 0...  ...
# Unnamed: 4                                                 NaN  ...
# Unnamed: 5                                                 NaN  ...
# Unnamed: 6                                                 NaN  ...
# Unnamed: 7                                                 NaN  ...
# Unnamed: 8                                                 NaN  ...
# Unnamed: 9                                                 NaN  ...
# Unnamed: 10                                                NaN  ...
# Unnamed: 11                                                0.5  ...
# Unnamed: 12                                                0.5  ...
# Unnamed: 13                         FX MM 100Mbit (оптический)  ...
# Unnamed: 14                                            PTP v.2  ...
# Unnamed: 15  колонна токовая 35кВ с жесткой шиной с воздушн...  ...
# Unnamed: 16                                                NaN  ...
# Unnamed: 17                                                NaN  ...
# Unnamed: 18                                                 35  ...
# Unnamed: 19                                            ТТЭО-35  ...
#
# Unnamed: 1                                            0  \
# Unnamed: 2   Внутренняя сборка для колонны/\nкаркас ГЧП
# Unnamed: 3                                          NaN
# Unnamed: 4                                          NaN
# Unnamed: 5                                          NaN
# Unnamed: 6                                          NaN
# Unnamed: 7                                          NaN
# Unnamed: 8                                          NaN
# Unnamed: 9                                          NaN
# Unnamed: 10                                         NaN
# Unnamed: 11                                         NaN
# Unnamed: 12                                         NaN
# Unnamed: 13                                         NaN
# Unnamed: 14                                         нет
# Unnamed: 15                                         NaN
# Unnamed: 16                                          1А
# Unnamed: 17                   клеммы на передней панели
# Unnamed: 18                               потенциальный
# Unnamed: 19                                         NaN
#
# Unnamed: 1                                             0  \
# Unnamed: 2                               Колонна токовая
# Unnamed: 3   Колонна токовая 35кВ ТТЭО-3.38.00.00.000-01
# Unnamed: 4                                           NaN
# Unnamed: 5                                           NaN
# Unnamed: 6                                           NaN
# Unnamed: 7                                           NaN
# Unnamed: 8                                           NaN
# Unnamed: 9                                           NaN
# Unnamed: 10                                          NaN
# Unnamed: 11                                          NaN
# Unnamed: 12                                          NaN
# Unnamed: 13                                          NaN
# Unnamed: 14                              версия Профотек
# Unnamed: 15                                          NaN
# Unnamed: 16                                          NaN
# Unnamed: 17                                          NaN
# Unnamed: 18                                          NaN
# Unnamed: 19                                          NaN
#
# Unnamed: 1                                                   1  \
# Unnamed: 2                                               Крейт
# Unnamed: 3   Корпус крейта 4U (220В, CrossV2.0) ТТЭО-3.04.0...
# Unnamed: 4                                                 NaN
# Unnamed: 5                                                 NaN
# Unnamed: 6                                                 NaN
# Unnamed: 7                                                 NaN
# Unnamed: 8                                                 NaN
# Unnamed: 9                                                 NaN
# Unnamed: 10                                                NaN
# Unnamed: 11                                                NaN
# Unnamed: 12                                                  З
# Unnamed: 13                                            Питание
# Unnamed: 14           основной - 230В AC,\nрезервный - 230В AC
# Unnamed: 15                                                 –2
# Unnamed: 16                                                  1
# Unnamed: 17                                                  2
# Unnamed: 18                                                  В
# Unnamed: 19                                                NaN
#
# Unnamed: 1                                     0  \
# Unnamed: 2                                 Кросс
# Unnamed: 3                                   NaN
# Unnamed: 4                                   NaN
# Unnamed: 5                                   NaN
# Unnamed: 6                                   NaN
# Unnamed: 7                                   NaN
# Unnamed: 8                                   NaN
# Unnamed: 9                                   NaN
# Unnamed: 10                                  NaN
# Unnamed: 11                                  NaN
# Unnamed: 12                                  NaN
# Unnamed: 13                                  NaN
# Unnamed: 14                                  NaN
# Unnamed: 15                                  NaN
# Unnamed: 16   1 вход постоянного или переменного
# Unnamed: 17  2 входа постоянного или переменного
# Unnamed: 18                                  БПР
# Unnamed: 19                                  NaN
#
# Unnamed: 1                                     1  \
# Unnamed: 2                       Панель передняя
# Unnamed: 3   Панель передняя ТТЭО-3.04.08.00.000
# Unnamed: 4                                   NaN
# Unnamed: 5                                   NaN
# Unnamed: 6                                   NaN
# Unnamed: 7                                   NaN
# Unnamed: 8                                   NaN
# Unnamed: 9                                   NaN
# Unnamed: 10                                  NaN
# Unnamed: 11                                  NaN
# Unnamed: 12                                    И
# Unnamed: 13                            термометр
# Unnamed: 14               оптический 3-канальный
# Unnamed: 15                                  NaN
# Unnamed: 16                            без буквы
# Unnamed: 17                                    П
# Unnamed: 18                                  NaN
# Unnamed: 19                                  NaN
#
# Unnamed: 1                                       1  \
# Unnamed: 2                       Модуль излучателя
# Unnamed: 3   Модуль излучателя ТТЭО-3.03.18.00.000
# Unnamed: 4                                     NaN
# Unnamed: 5                                     NaN
# Unnamed: 6                                     NaN
# Unnamed: 7                                     NaN
# Unnamed: 8                                     NaN
# Unnamed: 9                                     NaN
# Unnamed: 10                                    NaN
# Unnamed: 11                                    NaN
# Unnamed: 12                                    NaN
# Unnamed: 13                                    NaN
# Unnamed: 14                                    NaN
# Unnamed: 15                                    NaN
# Unnamed: 16          нет или встроенный оптический
# Unnamed: 17                проводной (электронный)
# Unnamed: 18                                    NaN
# Unnamed: 19                                    NaN
#
# Unnamed: 1                                             1  \
# Unnamed: 2                          Модуль температурный
# Unnamed: 3   Модуль температурный ТТЭО-3.04.05.00.000-04
# Unnamed: 4                                           NaN
# Unnamed: 5                                           NaN
# Unnamed: 6                                           NaN
# Unnamed: 7                                           NaN
# Unnamed: 8                                           NaN
# Unnamed: 9                                           NaN
# Unnamed: 10                                          NaN
# Unnamed: 11                                          NaN
# Unnamed: 12                                          NaN
# Unnamed: 13                                          NaN
# Unnamed: 14                                          NaN
# Unnamed: 15                                          NaN
# Unnamed: 16                                          NaN
# Unnamed: 17                                          NaN
# Unnamed: 18                                          NaN
# Unnamed: 19                                          NaN
#
# Unnamed: 1                                           1                      2  \
# Unnamed: 2                                Модуль 61850         Кабель питания
# Unnamed: 3   Модуль 61850 ПРОФОТЕК ТТЭО-3.04.13.00.000  Кабель питания КС.011
# Unnamed: 4                                         NaN                    NaN
# Unnamed: 5                                         NaN                    NaN
# Unnamed: 6                                         NaN                    NaN
# Unnamed: 7                                         NaN                    NaN
# Unnamed: 8                                         NaN                    NaN
# Unnamed: 9                                         NaN                    NaN
# Unnamed: 10                                        NaN                    NaN
# Unnamed: 11                                        NaN                    NaN
# Unnamed: 12                                        NaN                    NaN
# Unnamed: 13                                        NaN                    NaN
# Unnamed: 14                                        NaN                    NaN
# Unnamed: 15                                        NaN                    NaN
# Unnamed: 16                                        NaN                    NaN
# Unnamed: 17                                        NaN                    NaN
# Unnamed: 18                                        NaN                    NaN
# Unnamed: 19                                        NaN                    NaN
#
# Unnamed: 1                                                   0
# Unnamed: 2                                           Шкаф муфт
# Unnamed: 3   Шкаф муфт (1 муфта, 5 вводов) ВУИ09.00.00.000-021
# Unnamed: 4                                                 NaN
# Unnamed: 5                                                 NaN
# Unnamed: 6                                                 NaN
# Unnamed: 7                                                 NaN
# Unnamed: 8                                                 NaN
# Unnamed: 9                                                 NaN
# Unnamed: 10                                                NaN
# Unnamed: 11                                                NaN
# Unnamed: 12                                                NaN
# Unnamed: 13                                                NaN
# Unnamed: 14                                                NaN
# Unnamed: 15                                                NaN
# Unnamed: 16                                                NaN
# Unnamed: 17                                                NaN
# Unnamed: 18                                                NaN
# Unnamed: 19                                                NaN
#
# [18 rows x 97 columns]
